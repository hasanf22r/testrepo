# %%
import numpy as np
np.min([1, 2, 3])
np.max([1, 2, 3])
np.abs(-2)
# Out:
# 2

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
n=1000
data=np.exp(np.random.randn(n)/2)
k=40
plt.hist(data, bins=k)
plt.show()
